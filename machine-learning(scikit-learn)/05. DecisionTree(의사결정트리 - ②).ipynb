# %% [markdown]
# ## Decision Tree 실습

# %% [markdown]
# ### 1. max_depth 제약 없음

# %% [markdown]
# ## 1. 과적합 방지
#
# ### 1) max_depth(결정 트리의 최대 트리 깊이 제어)
# ####  max_depth  = 3

# %% [markdown]
# ### 2) min_samples_split : 자식 노드로 분할하기 위해 필요한 최소한의 갯수 지정

# %% [markdown]
# ### 3) min_samples_leaf : 리프 노드가 될 수 있는 샘플 데이터 건수의 최솟값 지정

# %% [markdown]
# # 사용자 행동 인식 데이터 세트
# http://archive.ics.uci.edu/ml/datasets/Human+Activity+Recognition+Using+Smartphones
#
# ![image.png](attachment:image.png)
