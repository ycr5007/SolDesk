# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# - 정답이 없는 데이터를 통해 데이터의 유의미한 패턴 / 구조 발견
# - 유사한 데이터 그룹화
