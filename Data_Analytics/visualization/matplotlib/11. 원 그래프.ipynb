# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
plt.rcParams['axes.unicode_minus'] = False # " - " 기호 Unicode 처리
plt.rcParams['font.family'] = 'Malgun Gothic' # 한글 폰트 설정

# %% [markdown]
# #### [실습1]

# %%
values = [30, 25, 20, 13, 10, 2]
labels = ['Python', 'Java', 'JavaScript', 'C#', 'C/C++', 'etc']

# %%
plt.pie(values, labels=labels, autopct="%.1f%%", startangle=90, counterclock=False)
# autopct = values 값 표현할 format 지정
# startangle = 시작 위치
# counterclock = startangle 의 진행 방향 지정
plt.show()

# %% [markdown]
# - autopct : 원 안에 표시할 % 포맷
# - startangle : 안 주는 경우 오른쪽 15도 정도에서 시작해서 시계 반대 방향으로 원이 돌아가게 됨, 각도를 주게 되면 그 각도를 기준으로 시계 반대 방향으로 원이 그려짐
# - counterclock=False : 시계 방향으로 원이 작성되도록 함

# %% [markdown]
# #### [실습2] 원 조각 내기

# %%
# 각 조각에 대한 비율 지정 ( 0 은 조각 X ), 데이터 개수만큼 배열의 크기를 정해줘야함
explode = [0.1, 0.1, 0, 0, 0, 0]

plt.pie(values, labels=labels, autopct="%.1f%%", startangle=90, counterclock=False, explode= explode)
plt.show()

# %%
# 각 조각에 대한 비율 지정 ( 0 은 조각 X ), 데이터 개수만큼 배열의 크기를 정해줘야함
explode = [0.05] * 6

plt.pie(values, labels=labels, autopct="%.1f%%", startangle=90, counterclock=False, explode= explode)
plt.show()

# %% [markdown]
# #### [실습3] 범례

# %%
explode = [0.05] * 6

plt.pie(values, labels=labels, autopct="%.1f%%", startangle=90, counterclock=False, explode= explode)
plt.legend()
plt.show()

# %%
explode = [0.05] * 6

plt.pie(values, labels=labels, autopct="%.1f%%", startangle=90, counterclock=False, explode= explode)
plt.legend(loc=(1.2, 0.3), title="언어별 선호도")
plt.show()

# %% [markdown]
# ## 심화

# %% [markdown]
# ### 1) 색상 변경

# %%
explode = [0.05] * 6
colors = ['#ffadad', '#ffd6a5', '#fdffb6', '#caffbf', '#9bf6ff', '#a0c4ff']

plt.pie(values, labels=labels, autopct="%.1f%%", startangle=90, counterclock=False, explode= explode, colors=colors)
plt.show()

# %% [markdown]
# ### 2) wedgeprops() : 도넛 모양 형태로 구성

# %%
explode = [0.05] * 6
colors = ['#ffadad', '#ffd6a5', '#fdffb6', '#caffbf', '#9bf6ff', '#a0c4ff']
wedgeprops = {'width':0.8}

plt.pie(values, labels=labels, autopct="%.1f%%", startangle=90, counterclock=False, explode= explode, colors=colors, wedgeprops=wedgeprops)
plt.show()

# %% [markdown]
# #### explode 대신에 wedgeprops 이용

# %%
colors = ['#ffadad', '#ffd6a5', '#fdffb6', '#caffbf', '#9bf6ff', '#a0c4ff']
wedgeprops = {'width':0.8, 'edgecolor':'w', 'linewidth':3}

plt.pie(values, labels=labels, autopct="%.1f%%", startangle=90, counterclock=False, colors=colors, wedgeprops=wedgeprops)
plt.show()

# %% [markdown]
# ### 3) autopct 커스텀

# %%
def custom_pct(pct):
    return ("%.1f%%" % pct) if pct >= 10 else ''

# %%
colors = ['#ffadad', '#ffd6a5', '#fdffb6', '#caffbf', '#9bf6ff', '#a0c4ff']
wedgeprops = {'width':0.8, 'edgecolor':'w', 'linewidth':3}

plt.pie(values, labels=labels, autopct=custom_pct, startangle=90, counterclock=False, colors=colors, wedgeprops=wedgeprops)
plt.show()

# %% [markdown]
# ### [실습]

# %%
df = pd.read_csv("../../data/student.csv", encoding='utf-8')
df
# Out:
#     이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 0  채치수  북산고  197   90   85  100  95  85      Python
# 1  정대만  북산고  184   40   35   50  55  25        Java
# 2  송태섭  북산고  168   80   75   70  80  75  Javascript
# 3  서태웅  북산고  187   40   70   70  75  80         NaN
# 4  강백호  북산고  188   15   20   10  35  10         NaN
# 5  변덕규  능남고  202   80  100   85  85  80           C
# 6  황태산  능남고  188   55   65   45  40  35      PYTHON
# 7  윤대협  능남고  190  100   85   90  95  95          C#

# %%
school = df.groupby('학교').size()

# %%
school['능남고']
# Out:
# 3

# %%
values = [school['능남고'], school['북산고']]
labels = ["능남고", "북산고"]

plt.pie(values, labels=labels, autopct='%.1f%%')
plt.title("소속 학교")
plt.show()
